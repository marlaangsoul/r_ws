# %%
library(ggplot2)
library(hflights)
library(ggthemes)
library('stringr')
library('rgl')
library('readxl')
library('foreign')
library('XML')
library('devtools')
library(dplyr)

# %%
install.packages('rgl')
# Out:
# package 'rgl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\NOTEBOOK\AppData\Local\Temp\RtmpyQY01x\downloaded_packages

# %%
library('rgl')

# %%
install.packages("devtools", dependencies=TRUE)
# Out:
# 'systemfonts', 'textshaping', 'rex', 'crosstalk', 'clisymbols', 'cyclocomp', 'xmlparsedata', 'downlit', 'ragg', 'parsedate', 'whoami', 'hunspell', 'BiocManager', 'covr', 'DT', 'foghorn', 'gmailr', 'lintr', 'mockery', 'pingr', 'pkgdown', 'rhub', 'spelling'(들)을 또한 설치합니다.
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# pkgdown  2.0.3  2.0.4             FALSE
#
# package 'systemfonts' successfully unpacked and MD5 sums checked
# package 'textshaping' successfully unpacked and MD5 sums checked
# package 'rex' successfully unpacked and MD5 sums checked
# package 'crosstalk' successfully unpacked and MD5 sums checked
# package 'clisymbols' successfully unpacked and MD5 sums checked
# package 'cyclocomp' successfully unpacked and MD5 sums checked
# package 'xmlparsedata' successfully unpacked and MD5 sums checked
# package 'downlit' successfully unpacked and MD5 sums checked
# package 'ragg' successfully unpacked and MD5 sums checked
# package 'parsedate' successfully unpacked and MD5 sums checked
# package 'whoami' successfully unpacked and MD5 sums checked
# package 'hunspell' successfully unpacked and MD5 sums checked
# package 'BiocManager' successfully unpacked and MD5 sums checked
# package 'covr' successfully unpacked and MD5 sums checked
# package 'DT' successfully unpacked and MD5 sums checked
# package 'foghorn' successfully unpacked and MD5 sums checked
# package 'gmailr' successfully unpacked and MD5 sums checked
# package 'lintr' successfully unpacked and MD5 sums checked
# package 'mockery' successfully unpacked and MD5 sums checked
# package 'pingr' successfully unpacked and MD5 sums checked
# package 'rhub' successfully unpacked and MD5 sums checked
# package 'spelling' successfully unpacked and MD5 sums checked
# package 'devtools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\NOTEBOOK\AppData\Local\Temp\RtmpyQY01x\downloaded_packages
# 소스형태의 패키지 'pkgdown'(들)를 설치합니다.

# %%
library(devtools)
# Out:
# 필요한 패키지를 로딩중입니다: usethis

# %%
install_github("gbm-developers/gbm") #개발자 버전 gbm 패키지 설치
# Out:
# WARNING: Rtools is required to build R packages, but is not currently installed.
#
# Please download and install Rtools 4.0 from https://cran.r-project.org/bin/windows/Rtools/.
#
# Downloading GitHub repo gbm-developers/gbm@HEAD
#
# WARNING: Rtools is required to build R packages, but is not currently installed.
#
# Please download and install Rtools 4.0 from https://cran.r-project.org/bin/windows/Rtools/.
#
# WARNING: Rtools is required to build R packages, but is not currently installed.
#
# Please download and install Rtools 4.0 from https://cran.r-project.org/bin/windows/Rtools/.
# Error: Failed to install 'gbm' from GitHub:
#   Could not find tools necessary to compile a package
# Call `pkgbuild::check_build_tools(debug = TRUE)` to diagnose the problem.
# Traceback:
#
# 1. install_github("gbm-developers/gbm")
# 2. pkgbuild::with_build_tools({
#  .     ellipsis::check_dots_used(action = getOption("devtools.ellipsis_action",
#  .         rlang::warn))
#  .     {
#  .         remotes <- lapply(repo, github_remote, ref = ref, subdir = subdir,
#  .             auth_token = auth_token, host = host)
#  .         install_remotes(remotes, auth_token = auth_token, host = host,
#  .             dependencies = dependencies, upgrade = upgrade, force = force,
#  .             quiet = quiet, build = build, build_opts = build_opts,
#  .             build_manual = build_manual, build_vignettes = build_vignettes,
#  .             repos = repos, type = type, ...)
#  .     }
#  . }, required = FALSE)
# 3. install_remotes(remotes, auth_token = auth_token, host = host,
#  .     dependencies = dependencies, upgrade = upgrade, force = force,
#  .     quiet = quiet, build = build, build_opts = build_opts, build_manual = build_manual,
#  .     build_vignettes = build_vignettes, repos = repos, type = type,
#  .     ...)
# 4. tryCatch(res[[i]] <- install_remote(remotes[[i]], ...), error = function(e) {
#  .     stop(remote_install_error(remotes[[i]], e))
#  . })
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. value[[3L]](cond)

# %%
# data load
df <- read.csv('./rggagi/example_studentlist.csv')
str(df)
# Out:
# 'data.frame':	17 obs. of  8 variables:
#  $ name     : chr  "김길동" "이미린" "홍길동" "김철수" ...
#  $ sex      : chr  "남자" "여자" "남자" "남자" ...
#  $ age      : int  23 22 24 23 20 21 22 23 23 22 ...
#  $ grade    : int  3 2 4 3 1 2 1 1 3 2 ...
#  $ absence  : chr  "유" "무" "무" "무" ...
#  $ bloodtype: chr  "O" "AB" "B" "AB" ...
#  $ height   : num  165 170 175 182 168 ...
#  $ weight   : num  68.2 53 80.1 85.7 49.5 52 45.3 55 64.2 61.3 ...

# %%
# 변수 1개
plot(df$age) #  첫 번째 행부터 마지막 행까지 산점도로 표시
# Out:
# plot without title

# %%
# 변수 2개 - 상관 관계
plot(df$height, df$weight)
# Out:
# plot without title

# %%
# 변수 2개 - 상관 관계 - 종속변수(y) ~ 독립변수(x)
plot(df$height ~ df$weight)
# Out:
# plot without title

# %%
# 수치형 변수, 명목형 변수 1 남자, 2 여자
plot(df$height, df$sex)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'ylim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$height, df$sex)
# 2. plot.default(df$height, df$sex)
# 3. localWindow(xlim, ylim, log, asp, ...)
# 4. plot.window(...)
# plot without title

# %%
# 명목 형 변수, 수치형 변수 1 남자, 2 여자
plot(df$sex, df$height)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'xlim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$sex, df$height)
# 2. plot.default(df$sex, df$height)
# 3. localWindow(xlim, ylim, log, asp, ...)
# 4. plot.window(...)
# plot without title

# %%
# 수치형 변수, 명목형 변수 1 남자, 2 여자
plot(df$height~ df$sex)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'xlim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$height ~ df$sex)
# 2. plot.formula(df$height ~ df$sex)
# 3. do.call(funname, c(list(mf[[i]], y, ylab = yl, xlab = xl), dots))
# 4. plot(c("남자", "여자", "남자", "남자", "여자", "여자", "여자",
#  . "여자", "남자", "남자", "남자", "남자", "남자", "여자", "여자",
#  . "남자", "남자"), c(165.3, 170.1, 175, 182.1, 168, 162, 155.2,
#  . 176.9, 178.5, 176.1, 167.1, 180, 162.2, 176.1, 158.2, 168.6,
#  . 169.2), ylab = "df$height", xlab = "df$sex")
# 5. plot.default(c("남자", "여자", "남자", "남자", "여자", "여자",
#  . "여자", "여자", "남자", "남자", "남자", "남자", "남자", "여자",
#  . "여자", "남자", "남자"), c(165.3, 170.1, 175, 182.1, 168, 162,
#  . 155.2, 176.9, 178.5, 176.1, 167.1, 180, 162.2, 176.1, 158.2,
#  . 168.6, 169.2), ylab = "df$height", xlab = "df$sex")
# 6. localWindow(xlim, ylim, log, asp, ...)
# 7. plot.window(...)
# plot without title

# %%
# 명목 형 변수~ 수치형 변수 1 남자, 2 여자
plot(df$sex~ df$height)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'ylim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$sex ~ df$height)
# 2. plot.formula(df$sex ~ df$height)
# 3. do.call(funname, c(list(mf[[i]], y, ylab = yl, xlab = xl), dots))
# 4. plot(c(165.3, 170.1, 175, 182.1, 168, 162, 155.2, 176.9, 178.5,
#  . 176.1, 167.1, 180, 162.2, 176.1, 158.2, 168.6, 169.2), c("남자",
#  . "여자", "남자", "남자", "여자", "여자", "여자", "여자", "남자",
#  . "남자", "남자", "남자", "남자", "여자", "여자", "남자", "남자"
#  . ), ylab = "df$sex", xlab = "df$height")
# 5. plot.default(c(165.3, 170.1, 175, 182.1, 168, 162, 155.2, 176.9,
#  . 178.5, 176.1, 167.1, 180, 162.2, 176.1, 158.2, 168.6, 169.2),
#  .     c("남자", "여자", "남자", "남자", "여자", "여자", "여자",
#  .     "여자", "남자", "남자", "남자", "남자", "남자", "여자", "여자",
#  .     "남자", "남자"), ylab = "df$sex", xlab = "df$height")
# 6. localWindow(xlim, ylim, log, asp, ...)
# 7. plot.window(...)
# plot without title

# %%
# 데이터 프레임 넣기
df2 <- data.frame(df$height, df$weight)
plot(df2)
# Out:
# plot without title

# %%
# 데이터 프레임 넣기
df3 <- data.frame(df2, df$age)
plot(df3)
# Out:
# plot without title

# %%
# 데이터 프레임 넣기
plot(df)
# Out:
# plot without title

# %%
# 성별 별도 표시
plot(df$weight~df$height, pch = as.integer(df$sex))
# Out:
# Warning message in FUN(X[[i]], ...):
# "강제형변환에 의해 생성된 NA 입니다"
# plot without title

# %%
# 성별 별도 표시 - 레전드 추가
plot(df$weight~df$height, pch = as.integer(df$sex))
legend('topleft', c('man', 'woman'), pch=df$sex)
# Out:
# Warning message in FUN(X[[i]], ...):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in legend("topleft", c("man", "woman"), pch = df$sex):
# "not using pch[2..] since pch[1L] has multiple chars"
# plot without title

# %%
# 성별에 따른 키와 몸무게
coplot(df$weight ~ df$height | df$sex)
# Out:
# plot without title

# %%
# 저수준 그래프 함수
# 제목 달기 - ann = F 모든 라벨 삭제
plot(df$weight ~ df$height, ann=F)
title(main = '몸무게와 키의 상관관계')
title(ylab = '몸무게')
title(xlab = '키')
grid() # 격자 추가
abline(v=mean(df$height),h=mean(df$weight), col='red')
# Out:
# Plot with title "몸무게와 키의 상관관계"

# %%
blood_type <- table(df$bloodtype)
blood_type
# Out:
#  A AB  B  O
#  4  3  5  5

# %%
barplot(blood_type)
title(main = '혈액형 빈도수')
title(xlab = '혈액형')
title(ylab = '빈도수')
# Out:
# Plot with title "혈액형 빈도수"

# %%
# 그룹별 평균
height_blood <- tapply(df$height, df$bloodtype, mean)
height_blood
# Out:
#       A      AB       B       O
# 169.075 177.400 171.280 165.140

# %%
barplot(height_blood, ylim=c(0,200))
# Out:
# plot without title

# %%
# 빈도수는 plot() 바로 그릴 수 있음
plot(df$bloodtype)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'ylim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$bloodtype)
# 2. plot.default(df$bloodtype)
# 3. localWindow(xlim, ylim, log, asp, ...)
# 4. plot.window(...)
# plot without title

# %%
boxplot(df$height)
# Out:
# plot without title

# %%
par(mfrow = c(2,3))
plot(df$height, df$weight)
plot(df$sex, df$height)
barplot(table(df$bloodtype))
boxplot(df$height)
boxplot(df$height~df$bloodtype)
hist(df$height, breaks = 10)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'xlim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$sex, df$height)
# 2. plot.default(df$sex, df$height)
# 3. localWindow(xlim, ylim, log, asp, ...)
# 4. plot.window(...)

# %%
boxplot(df$height)
# Out:
# plot without title

# %%
# levels 별 
boxplot(df$height ~ df$bloodtype)
# Out:
# plot without title

# %%
subset(df,subset=(df$bloodtype=='O'))
# Out:
#    name   sex  age grade absence bloodtype height weight
# 1  김길동 남자 23  3     유      O         165.3  68.2
# 6  박미희 여자 21  2     무      O         162.0  52.0
# 7  강수친 여자 22  1     무      O         155.2  45.3
# 11 박수호 남자 24  4     유      O         167.1  62.0
# 14 이희진 여자 23  3     무      O         176.1  53.1

# %%
hist(df$height)
# Out:
# Plot with title "Histogram of df$height"

# %%
# 막대수 조정
hist(df$height, breaks = 10)
# Out:
# Plot with title "Histogram of df$height"

# %%
# 상대도수 밀도 prob = T, 곡선 추가 lines
# 바의 면적이 상대도수
hist(df$height, breaks = 10, prob = T)
lines(density(df$height))
# Out:
# Plot with title "Histogram of df$height"

# %%
# 계급 7간견 만들기
break_point <- seq(min(df$height), max(df$height)+7, by=7)
hist(df$height, breaks = break_point)
# Out:
# Plot with title "Histogram of df$height"

# %%
# 계급 수동 설정 => 상대밀도함수(Density) 로 바뀜
diff_point <- c(min(df$height), 165, 170, 180, 185)
hist(df$height, breaks = diff_point)
# Out:
# Plot with title "Histogram of df$height"

# %%
par(mfrow = c(2,3))
plot(df$weight, df$height)
plot(df$sex, df$height)
barplot(table(df$bloodtype))
boxplot(df$height)
boxplot(df$height ~ df$bloodtype)
hist(df$height, breaks = 10)
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# Error in plot.window(...): 유한한 값들만이 'xlim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$sex, df$height)
# 2. plot.default(df$sex, df$height)
# 3. localWindow(xlim, ylim, log, asp, ...)
# 4. plot.window(...)

# %%
# 다시 1개씩 그리기
par(mfrow = c(1,1))

# %%
plot(df$weight~df$height + df$age + df$grade + df$absence + df$sex)
# Out:
# plot without title
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# "강제형변환에 의해 생성된 NA 입니다"
# Warning message in min(x):
# "min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다"
# Warning message in max(x):
# "max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다"
# plot without title
# Error in plot.window(...): 유한한 값들만이 'xlim'에 사용될 수 있습니다
# Traceback:
#
# 1. plot(df$weight ~ df$height + df$age + df$grade + df$absence +
#  .     df$sex)
# 2. plot.formula(df$weight ~ df$height + df$age + df$grade + df$absence +
#  .     df$sex)
# 3. do.call(funname, c(list(mf[[i]], y, ylab = yl, xlab = xl), dots))
# 4. plot(c("유", "무", "무", "무", "유", "무", "무", "무", "무",
#  . "무", "유", "무", "무", "무", "무", "유", "무"), c(68.2, 53,
#  . 80.1, 85.7, 49.5, 52, 45.3, 55, 64.2, 61.3, 62, 75.8, 55.3, 53.1,
#  . 45.2, 70.2, 62.2), ylab = "df$weight", xlab = "df$absence")
# 5. plot.default(c("유", "무", "무", "무", "유", "무", "무", "무",
#  . "무", "무", "유", "무", "무", "무", "무", "유", "무"), c(68.2,
#  . 53, 80.1, 85.7, 49.5, 52, 45.3, 55, 64.2, 61.3, 62, 75.8, 55.3,
#  . 53.1, 45.2, 70.2, 62.2), ylab = "df$weight", xlab = "df$absence")
# 6. localWindow(xlim, ylim, log, asp, ...)
# 7. plot.window(...)
# plot without title
# plot without title

# %%
# 시계열 변수 임의로 만들기
runif(30) # 난수 발생
round(runif(30)*100) # 소수점 처리
TS1 <- c(round(runif(30)*100))
TS1
# Out:
#  [1] 0.6354297 0.5093421 0.1239436 0.5438858 0.4524718 0.3299527 0.4129238
#  [8] 0.6059274 0.5721167 0.8298619 0.2130827 0.6776031 0.1250808 0.4666328
# [15] 0.3165118 0.8658780 0.7869779 0.3178010 0.0311363 0.7588719 0.6921118
# [22] 0.8121742 0.1727759 0.7685500 0.3687595 0.3090157 0.8422254 0.7031262
# [29] 0.3651624 0.8752152
#  [1] 46 32 92 32 57 63 86 76 14  1 95 72 28 22 14 44  2 22 91  9 25 32 97 71 95
# [26] 94 29 73 82 27
#  [1] 91 94 37 78 75 51 97 66 63  9  0 43  9 51 51 86 15 92 69 84 62 69 90 94 24
# [26] 33 70 53 25 68

# %%
TS2 <- c(round(runif(30)*100))
TS2
# Out:
#  [1] 44 39  9 38 84  4 30 63 52 20 90 63 56  8 57 37 33 49 62 10 58 58 26 84 48
# [26] 94 65 42 39 79

# %%
# 자료 정렬
TS1 <- sort(TS1, decreasing = F)
TS2 <- sort(TS2, decreasing = F)
TS1
TS2
# Out:
#  [1]  0  9  9 15 24 25 33 37 43 51 51 51 53 62 63 66 68 69 69 70 75 78 84 86 90
# [26] 91 92 94 94 97
#  [1]  4  8  9 10 20 26 30 33 37 38 39 39 42 44 48 49 52 56 57 58 58 62 63 63 65
# [26] 79 84 84 90 94

# %%
plot(TS1, type = 'l')
# Out:
# plot without title

# %%
plot(TS1, type = 'l')
lines(TS2, lty='dashed', col='red')
# Out:
# plot without title

# %%
x1 <- seq(1,100,1)
y1 <- dbinom(x1, 100, 0.25) # dbinom(v,n,p) B(n,p)이항 분포 함수 값 만들기
head(y1)
# Out:
# [1] 1.069067e-11 1.763961e-10 1.920758e-09 1.552613e-08 9.936720e-08
# [6] 5.244380e-07

# %%
x2 <- seq(1,50,1)
y2 <- dbinom(x2, 50, 0.5) # dbinom(v,n,p) B(n,p)이항 분포 함수 값 만들기
head(y2)
# Out:
# [1] 4.440892e-14 1.088019e-12 1.740830e-11 2.045475e-10 1.881837e-09
# [6] 1.411378e-08

# %%
plot(x1, y1, type = 'h', ylim = c(0,0.15), xlim = c(0,60))
lines(x2, y2, col='red')
# Out:
# plot without title

# %%
library('ggplot2')
library('ggthemes')

# %%
g1 <- ggplot(data=diamonds, aes(x=carat, y=price, colour=clarity))
g2 <- geom_point()
g3 <- theme_wsj()

# %%
g1+g2+g3
# Out:
# plot without title

# %%
# 테마만 바꾸기
g1 + g2 + theme_bw()
# Out:
# plot without title

# %%
# 데이터 로드
df <- read.csv('./rggagi/example_studentlist.csv')

# %%
g1 <- ggplot(df, aes(x=height, y=weight, colour=bloodtype))

# %%
g1 + geom_point()
# Out:
# plot without title

# %%
g1 + geom_line()
# Out:
# plot without title

# %%
g1 + geom_point() + geom_line()
# Out:
# plot without title

# %%
g1 + geom_line(aes(colour=sex)) + geom_point(size=10)
# Out:
# plot without title

# %%
g1 + geom_point(size=10) + geom_line(size=1) + facet_grid(.~sex) # 성별 독립변수
# Out:
# plot without title

# %%
g1 + geom_point(size=10) + geom_line(size=1) + facet_grid(sex~.) # 성별 종속변수
# Out:
# plot without title

# %%
# y축 범위(scale) 각각 맞게 처리
g1 + geom_point(size=10) + geom_line(size=1) + facet_grid(sex~., scale='free') # 성별 종속변수
# Out:
# plot without title

# %%
# y축 scale 적용 안됨
g1 + geom_point(size=10) + geom_line(size=1) + facet_grid(.~sex, scale='free') # 성별 독립변수
# Out:
# plot without title

# %%
# y축 scale 적용
g1 + geom_point(size=10) + geom_line(size=1) + facet_wrap(~sex, scale='free') # 성별 독립변수
# Out:
# plot without title

# %%
# facet_grid() - 명목형 변수들의 level 별 그래프를 보여주는 목적
g <- ggplot(mpg, aes(displ, hwy)) # 배기량, 고속도로연비 산점도
g + geom_point()
# Out:
# plot without title

# %%
# 차량 종류에 따른 배기량, 고속도로연비 보기
g + geom_point() + facet_grid(.~class)
# Out:
# plot without title

# %%
# 종속변수 추가
g + geom_point(alpha=.3) + facet_grid(cyl~class, scale='free')
# Out:
# plot without title

# %%
# 종속변수 추가 - 각각의 그래프를 모아서 보기 위함
g + geom_point(alpha=.3) + facet_wrap(cyl~class, scale='free')
# Out:
# plot without title

# %%
ggplot(df, aes(x=bloodtype)) + geom_bar()
# Out:
# plot without title

# %%
# Level 별 색 넣기 - fill
ggplot(df, aes(x=bloodtype, fill=sex)) + geom_bar()
# Out:
# plot without title

# %%
# Level 별 색 넣고 가각 바로 표시 - position
ggplot(df, aes(x=bloodtype, fill=sex)) + geom_bar(position = 'dodge')
# Out:
# plot without title

# %%
# Level 별 색 넣고 가각 바로 표시 - position
ggplot(df, aes(x=bloodtype, fill=sex)) + geom_bar(position = 'identity') # 누적없이 겹치기
# Out:
# plot without title

# %%
# Level 별 색 넣고 가각 바로 표시 - position
ggplot(df, aes(x=bloodtype, fill=sex)) + geom_bar(position = 'fill') # 비율로 표시
# Out:
# plot without title

# %%
# 막대 넓이 바꾸기 - width
ggplot(df, aes(x=bloodtype, fill=sex)) + geom_bar(position = 'dodge', width = 0.5)
# Out:
# plot without title

# %%
# 도수 값 말고 계산된 값 사용하기 - 혈액형별 키 평균
height_mean <- tapply(df$height, df$bloodtype, mean)
height_mean
# Out:
#       A      AB       B       O
# 169.075 177.400 171.280 165.140

# %%
# 변수명 주기
df2 <- data.frame(height_mean)
df2$bloodtype <- rownames(df2)
rownames(df2) <- NULL

# %%
df2
# Out:
#   height_mean bloodtype
# 1 169.075     A
# 2 177.400     AB
# 3 171.280     B
# 4 165.140     O

# %%
# stat = 'identity' 값그대로, 생략시 stat = 'bin'  빈도수 표시
ggplot(df2, aes(x=bloodtype, y=height_mean, fill=bloodtype)) +
geom_bar(stat = 'identity') +
scale_fill_brewer()
# Out:
# plot without title

# %%
g1 <- ggplot(diamonds, aes(x=carat))

# %%
# y축 계급 빈도수
g1 + geom_histogram(binwidth = 0.1, fill='orange')
# Out:
# plot without title

# %%
# 예약어 - ..count..도수 default
g1 + geom_histogram(aes(y=..count..), binwidth = 0.1, fill='orange')
# Out:
# plot without title

# %%
# 예약어 - ..ncount.. 표준화된 도수
g1 + geom_histogram(aes(y=..ncount..), binwidth = 0.1, fill='orange')
# Out:
# plot without title

# %%
# 예약어 - ..density.. 밀도
g1 + geom_histogram(aes(y=..density..), binwidth = 0.1, fill='orange')
# Out:
# plot without title

# %%
# 예약어 - ..ndensity.. 표준화된 밀도
g1 + geom_histogram(aes(y=..ndensity..), binwidth = 0.1, fill='orange')
# Out:
# plot without title

# %%
# 그룹별로 그리기 - facet_grid
g1 + geom_histogram(binwidth = 0.1, fill='orange') +
facet_grid(color~.) # color 변수 Level 별로
# Out:
# plot without title

# %%
# 그룹별로 그리기 - 축변경 facet_grid - scales='free'
g1 + geom_histogram(binwidth = 0.1, fill='orange') +
facet_grid(color~., scales='free') # color 변수 Level 별로
# Out:
# plot without title

# %%
# Level 별로 겹처 보이기
g1 + geom_histogram(aes(fill=color), binwidth = 0.1, alpha=0.5)
# Out:
# plot without title

# %%
# 데이터 로드
df <- read.csv('rggagi/example_studentlist.csv')
head(df)
# Out:
#   name   sex  age grade absence bloodtype height weight
# 1 김길동 남자 23  3     유      O         165.3  68.2
# 2 이미린 여자 22  2     무      AB        170.1  53.0
# 3 홍길동 남자 24  4     무      B         175.0  80.1
# 4 김철수 남자 23  3     무      AB        182.1  85.7
# 5 손세수 여자 20  1     유      A         168.0  49.5
# 6 박미희 여자 21  2     무      O         162.0  52.0

# %%
g1 <- ggplot(df, aes(x=weight, y=height))

# %%
g1 + geom_point()
# Out:
# plot without title

# %%
# Level 별 색상 주기
g1 + geom_point(aes(colour=sex), size=7)
# Out:
# plot without title

# %%
# 점 모양 바꾸기 1
g1 + geom_point(aes(colour=sex, shape=sex), size=7)
# Out:
# plot without title

# %%
# 점 모양 바꾸기 2
g1 + geom_point(aes(colour=sex, shape=bloodtype), size=7)
# Out:
# plot without title

# %%
# colour  에 연속형 변수 넣기
g1 + geom_point(aes(colour=height, shape=sex), size=7)
# Out:
# plot without title

# %%
# size  에 연속형 변수 넣기
g1 + geom_point(aes(size=height, shape=sex), colour='orange')
# Out:
# plot without title

# %%
# 산점도로 회귀분석의 그리기
g1 + geom_point(aes(colour=sex), size=7) +
geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# 점마다 이름 넣기 - geom_text()
g1 + geom_point(aes(colour=sex), size=7) +
geom_text(aes(label=name))
# Out:
# plot without title

# %%
# 점마다 이름 넣기 - 위치조절 vjust, 글자색 colour
g1 + geom_point(aes(colour=sex), size=7) +
geom_text(aes(label=name), vjust=-1.5, colour='grey35')
# Out:
# plot without title

# %% [markdown]
# theme() - 만들어져 있는 테마 사용
# - themes_wsj() : 월스트릿저널에서 많이 사용하는 그래프 스타일

# %% [markdown]
# http://www.cookbook-r.com/
#
# R 공부할때 좋은 책

# %% [markdown]
# 좋은 블로그
#
# https://m.blog.naver.com/cnrrn214/221764559893
